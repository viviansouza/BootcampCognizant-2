# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv",sep=";",parse_dates=["ocorrencia_dia"],dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# ...

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0

# %%
df.loc[[10,40]] #linha 10 a 40
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              45332               45332                 ACIDENTE
# 40              45415               45415                 ACIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10            VIAMÃO            RS                 ****     2012-01-09
# 40    RIO DE JANEIRO            RJ                 ****     2012-01-30
#
#    ocorrencia_hora  total_recomendacoes
# 10        13:30:00                    0
# 40        13:55:00                    0

# %%
df.loc[:,'ocorrencia_cidade'] # todos os dados de uma coluna
# Out:
# 0        PORTO ALEGRE
# 1           GUARULHOS
# 2              VIAMÃO
# 3       SÃO SEBASTIÃO
# 4            SÃO SEPÉ
#             ...
# 5162            JATAÍ
# 5163          MARACAÍ
# 5164    NOVO HAMBURGO
# 5165         CURITIBA
# 5166        PETROLINA
# Name: ocorrencia_cidade, Length: 5167, dtype: object

# %%
df.codigo_ocorrencia.is_unique # verificar se o cod da ocorrencia é único para cada linha
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True) # codigo_ocorrencia vira o índice

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df.loc[45401]
# Out:
# codigo_ocorrencia2                        45401
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                 SÃO SEBASTIÃO
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora                        17:00:00
# total_recomendacoes                           0
# Name: 45401, dtype: object

# %%
df.reset_index(drop=True, inplace=True) #resetar o dataframe

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                 ****     2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0
# 3                    0
# 4                    0

# %%
df.loc[2,'ocorrencia_aerodromo'] = '' #colocar vazio onde tem asterisco

# %%
df.head(3)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0

# %%
df['ocorrencia_uf_backup'] = df.ocorrencia_uf # criar coluna de backup

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes ocorrencia_uf_backup
# 0                    0                   RS
# 1                    3                   SP
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP',] #Obter todos de São Paulo
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 1                  45331                 ACIDENTE          GUARULHOS
# 3                  45401                 ACIDENTE      SÃO SEBASTIÃO
# 5                  52243                INCIDENTE            UBATUBA
# 6                  50713          INCIDENTE GRAVE           CAMPINAS
# 13                 45408                 ACIDENTE           ELDORADO
# ...                  ...                      ...                ...
# 5148               80441                 ACIDENTE  BRAGANÇA PAULISTA
# 5157               80453                INCIDENTE           CAMPINAS
# 5158               80454          INCIDENTE GRAVE          ARAÇATUBA
# 5161               80456                INCIDENTE          SÃO PAULO
# 5163               80452                 ACIDENTE            MARACAÍ
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %% [raw]
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ####
# ###!
# *****
# ****
# ocorrencia_hora
# NULL

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
# 3            SP                 ****     2012-01-06        17:00:00
# 4            RS                 ****     2012-01-06        16:30:00
#
#    total_recomendacoes ocorrencia_uf_backup
# 0                    0                   RS
# 1                    3                   SP
# ...

# %%
df.loc[df.ocorrencia_aerodromo == '####', ['ocorrencia_aerodromo']]= pd.NA #atribuir valores que não estão disponíveis dentro de uma célula

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
# 3            SP                   10     2012-01-06        17:00:00
# 4            RS                   10     2012-01-06        16:30:00
#
#    total_recomendacoes
# 0                   10
# 1                    3
# 2                   10
# 3                   10
# 4                   10

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']]=pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05        20:27:00
# 1            SP                 SBGR     2012-01-06        13:44:00
# 2            RS                          2012-01-06        13:00:00
# 3            SP                 <NA>     2012-01-06        17:00:00
# 4            RS                 <NA>     2012-01-06        16:30:00
#
#    total_recomendacoes ocorrencia_uf_backup
# 0                    0                   RS
# 1                    3                   SP
# ...

# %%
df.replace(['####','**','###!','*****','****','NULL'], pd.NA, inplace=True) #alterações em todo dataset

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.isna().sum()  #informa qtos dados não informados
# Out:
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.isnull().sum()  # outra forma de saber dados não informados
# Out:
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %% [raw]
# df.fillna(0) #coloca um valor nos dados não informados, em tempo de visualização

# %% [raw]
# df.fillna(10, inplace=True)#para realmente alterar

# %%
df.replace([0], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.fillna(value={'total_recomendacoes':10},inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                  52242                INCIDENTE      PORTO ALEGRE
# 1                  45331                 ACIDENTE         GUARULHOS
# 2                  45333                 ACIDENTE            VIAMÃO
# 3                  45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                  45407                 ACIDENTE          SÃO SEPÉ
# ...                  ...                      ...               ...
# 5162               80458                 ACIDENTE             JATAÍ
# 5163               80452                 ACIDENTE           MARACAÍ
# 5164               80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165               80460                INCIDENTE          CURITIBA
# 5166               80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.drop(['ocorrencia_uf_backup'], axis=1, inplace=True) #excluir coluna de backup

# %%
df
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0                 52242                INCIDENTE      PORTO ALEGRE
# 1                 45331                 ACIDENTE         GUARULHOS
# 2                 45333                 ACIDENTE            VIAMÃO
# 3                 45401                 ACIDENTE     SÃO SEBASTIÃO
# 4                 45407                 ACIDENTE          SÃO SEPÉ
# ...                 ...                      ...               ...
# 5162              80458                 ACIDENTE             JATAÍ
# 5163              80452                 ACIDENTE           MARACAÍ
# 5164              80457          INCIDENTE GRAVE     NOVO HAMBURGO
# 5165              80460                INCIDENTE          CURITIBA
# 5166              80467                INCIDENTE         PETROLINA
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RS                 SBPA     2012-01-05        20:27:00
# ...

# %%
df.drop_duplicates(inplace=True) #exclui linhas duplicadas fazendo a alteração
